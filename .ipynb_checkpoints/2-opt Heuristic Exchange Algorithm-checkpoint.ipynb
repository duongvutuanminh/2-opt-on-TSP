# %% [markdown]
# # Introduction about the TSP problem and the 2-opt algorithm

# %% [markdown]
# ### Travelling Salesman Problem (TSP)
#     TSP is the problem of finding the shortest possible route(tour) for a person to take given a list of specific destinations.
#     TSP belongs to the NP-Hard problems. In simple words, it means that you can not guarantee to find the shortest path within a reasonable time limit.
#
#     If you try to brute-force every possible combination and choose the best value one, it will run in O(n!) time. An average computer has a clock speed of 2.8 GHz which can perform about 2.8 billion calculations per second. Thus, a set of 20 nodes will take more than 27 years to give you the optimal answer :(
#
#     There are algorithms,like dynamic programming or DP method guarantees to find the best answer to TSP. However, its time complexity (O(n^2*2^n)) would exponentially increase with the number of cities.
#
#     What we need is a heuristic(approximate) algorithm to generate a good enough (not optimal) solution in polynomial time complexity and 2-opt is a great example.
#
# ![image.png](attachment:image.png)
#
# ### 2-opt algorithm
#     The 2-opt algorithm is a simple local search method with a special swapping mechanism that works as its heuristic.
#
#     Theoretically, r-opt heuristic algorithm (r = 1,2,3,...) improve a feasible tour (can be generate by naive algorithms like nearest-neighbor) by deleting r edges and replacing with r new edges. If the exchange tour is better than the current tour then it becomes the current tour. If not, then another attempt to exchange r more edges is carried out. This process repeats until a shortest path is found. The running time for r-opt heuristic algorithm is O(n^r) where n is the number of nodes.

# %% [markdown]
# # Execution and visualization

# %%
#importing libs 
import time 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Node and Graph class

# %%
class Node:
    def __init__(self, node_number, x, y):
        self.node_number = str(node_number)
        self.x = float(x)
        self.y = float(y)
        
    def __str__(self):
        return "Node " + self.node_number

# %%
class Graph:
    global city_name
    def __init__(self, node_list, algo_name : str = None, tour = []):
        self.node_list = node_list
        self.city_name = city_name
        self.algo_name = algo_name
        self.tour = tour 
        
    def draw(self):
        plt.figure(figsize = (14,7))
        plt.scatter([item.x for item in node_list], [item.y for item in self.node_list], color = 'blue')

        for n in range(dim):
            plt.annotate(str(n), xy=(self.node_list[n].x, self.node_list[n].y), xytext = (self.node_list[n].x-0.1, self.node_list[n].y+0.1), color = 'black')

        if len(self.tour) != 0:
            for n in range(len(self.tour)-1):
                point1 = [self.node_list[self.tour[n]].x,self.node_list[self.tour[n+1]].x]
                point2 = [self.node_list[self.tour[n]].y,self.node_list[self.tour[n+1]].y]
                plt.plot(point1, point2, color= 'red')

        plt.xlabel("X")
        plt.ylabel("Y")
        if self.algo_name is None: 
            plt.title("Graph for nodes in {0} data set".format(self.city_name))
        else:
            plt.title("Graph for nodes in {0} data set using the {1} algorithm".format(self.city_name, self.algo_name))
        return plt.show()

# %% [markdown]
# ### Data input and selection of files
# Note: more data sets from http://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/

# %%
file_name = input("Enter the name of the data set you want to use: ")
if file_name[-4:] != ".tsp":
    file_name += ".tsp"
    
with open("data_set/" + file_name, 'r') as file:
    for line in file:
        if line.startswith("NAME"):
            city_name = line.strip().split()[-1]
        elif line.startswith("DIMENSION"):
            dim = int(line.strip().split()[-1])
        elif line.startswith("NODE_COORD"):
            # A list of node objects 
            node_list = []
            # A list contains tuples of edge 
            node_edges = [(i,j) for i in range(dim) for j in range(dim) if i!=j]
            for i in range(int(dim)):
                node, x, y = next(file).strip().split()
                node_list.append(Node(int(node)-1,x,y))
# Out:
# Enter the name of the data set you want to use: berlin52

# %% [markdown]
# ### Plotting nodes into the graph (no edges)

# %%
basic_graph = Graph(node_list)
basic_graph.draw()

# %% [markdown]
# ### Calculating the distance between 2 nodes

# %%
distances = {(i,j):((node_list[i].x-node_list[j].x)**2 + (node_list[i].y-node_list[j].y)**2)**0.5 for i,j in node_edges}

# %% [markdown]
# ### Total distance function
#     This function helps calculating the distance/cost of a specific tour of the graph

# %%
def total_distance(tour, distances):
    distance = 0
    for n in range(len(tour)-1):
        distance += distances[(tour[n],tour[n+1])]
    return distance

# %% [markdown]
# ### Init a feasible solution using Nearest-Neighbor algorithm

# %%
def nearest_neighbor(node_list, distances, dim, starting_node=0):
    res = [starting_node]
    
    while len(res) < dim:
        i = res[-1]
        nn = {(i,j): distances[(i,j)] for j in range(dim) if j != i and j not in res}
        new_edge = min(nn.items(), key = lambda x: x[1])
        res.append(new_edge[0][1])
        
    res.append(starting_node)
    return res, total_distance(res, distances)

# %%
#timer on, nearest_neighbor, timer off
start_time = time.time() 
tour_nn, tour_nn_distance = nearest_neighbor(node_list, distances, dim)
finish_time = time.time()

time_taken = finish_time - start_time

#Make a graph of connected nodes
tour_nn_graph = Graph(node_list, "Nearest-Neighbor", tour_nn)

# %%
print("Nearest-Neighbor tour: {0}\nTotal tour distance: {1}\nTime complexity: O(n^2)\nActual time taken: {2}".format(tour_nn, tour_nn_distance, time_taken))
tour_nn_graph.draw()
# Out:
# Nearest-Neighbor tour: [0, 21, 48, 31, 35, 34, 33, 38, 39, 37, 36, 47, 23, 4, 14, 5, 3, 24, 45, 43, 15, 49, 19, 22, 30, 17, 2, 18, 44, 40, 7, 9, 8, 42, 32, 50, 11, 27, 26, 25, 46, 12, 13, 51, 10, 28, 29, 20, 16, 41, 6, 1, 0]
# Total tour distance: 8980.918279329191
# Time complexity: O(n^2)
# Actual time taken: 0.003992557525634766

# %% [markdown]
# ### Try to optimize the available solution using 2-opt

# %%
def algo_2opt(avail_tour, distances):
    
    
    for i in range(len(avail_tour) - 2):
        optimal_change = 0
        for j in range(i+2, len(avail_tour)-1):
            old_cost = distances[(avail_tour[i], avail_tour[i+1])] + distances[(avail_tour[j], avail_tour[j+1])]
            new_cost = distances[(avail_tour[i], avail_tour[j])] + distances[(avail_tour[i+1], avail_tour[j+1])]
            change = new_cost - old_cost
            
            if change < optimal_change: 
                optimal_change = change
                optimal_i, optimal_j = i, j
        
        #if we found an optimal swapped edges (just one optimal pair for each node i), then update the tour
        if optimal_change < 0:
            avail_tour[optimal_i+1:optimal_j+1] = avail_tour[optimal_i+1:optimal_j+1][::-1]
        
    return avail_tour, total_distance(avail_tour, distances)

# %%
tour_nn_clone = tour_nn[:]

#timer on, 2-opt, timer off
start_time = time.time() 
tour_2opt, tour_2opt_distance = algo_2opt(tour_nn_clone, distances)
finish_time = time.time()

time_taken = finish_time - start_time

#Make a graph of connected nodes
tour_2opt_graph = Graph(node_list, "2-opt", tour_2opt)

# %%
print("2-opt tour: {0}\nTotal tour distance: {1}\nTime complexity: O(n^2)\nActual time taken: {2}".format(tour_2opt, tour_2opt_distance, time_taken))
tour_2opt_graph.draw()
# Out:
# 2-opt tour: [0, 21, 1, 6, 41, 16, 20, 30, 17, 2, 44, 18, 40, 7, 8, 9, 42, 32, 50, 10, 51, 13, 12, 11, 27, 26, 25, 46, 28, 29, 22, 19, 49, 15, 43, 45, 24, 3, 5, 14, 4, 23, 47, 37, 36, 39, 38, 33, 34, 35, 48, 31, 0]
# Total tour distance: 8402.043722390876
# Time complexity: O(n^2)
# Actual time taken: 0.0019948482513427734

# %% [markdown]
# ### Conclusion

# %% [markdown]
# So by using the 2-opt heuristic exchange algorithm, the final solution has been improved by approx 6.5%.<br>
# The optimal solution of the berlin52 set is 7542, from the library of TSPLIB, which is a 16% improvement compare to the nearest-neighbor algorithm.<br>
# Of course, this percentage can vary greatly with larger data set. Try out on your own using the source code in the GitHub repo.

# %% [markdown]
# # Reference

# %% [markdown]
# https://towardsdatascience.com/how-to-solve-the-traveling-salesman-problem-a-comparative-analysis-39056a916c9f<br>
# Solving travelling salesman problems with heuristic learning approach (Research paper by Sim Kim Lau - 2002)<br>
# Grooking Algorithm (Book by Aditya Y.Bhargava)<br>
# A High-Speed 2-Opt TSP Solver for Large Problem Sizes (Lecture slides from Martin Burtscher - University of Texas)<br>
# https://stemlounge.com/animated-algorithms-for-the-traveling-salesman-problem/<br>
# Data set: http://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/
# Pics: https://scipbook.readthedocs.io/en/latest/_images/tsp.png
